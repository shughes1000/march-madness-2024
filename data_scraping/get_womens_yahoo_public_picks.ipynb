# %% [markdown]
# # Get Yahoo Public Picks

# %% [markdown]
# Used to compare my picks with general public concensus. Assumes yahoo data has been exported to Excel.

# %%
season = 2024

season
# Out:
# 2024

# %%
import pandas as pd

pd.set_option('display.max_columns', 100)

df = pd.concat(
    [
        pd.read_excel(fr'..\data\unprocessed\womens_yahoo\{season}_womens_yahoo_picks.xlsx', sheet_name=f'round_{round_}')
        .assign(Round=round_)
        for round_ in range(1, 7)
    ],
    ignore_index=True,
)

df['Seed'] = df['Team (Seed)'].str.extract(r'\((\d+)\)').astype(int)
df['Team (Seed)'] = df['Team (Seed)'].str.replace(r'\(\d+\)', '', regex=True)

df.rename(columns={'Team (Seed)': 'Team'}, inplace=True)

df = df.pivot(index=['Team', 'Seed'], columns=['Round'], values='% Picked').reset_index()
df.columns = ['Team', 'Seed', 'Round 1', 'Round 2', 'Round 3', 'Round 4', 'Round 5', 'Round 6']

df
# Out:
#                   Team  Seed  Round 1  Round 2  Round 3  Round 4  Round 5  \
# 0             AUB/ARIZ    11   0.1524   0.0182   0.0066   0.0027   0.0011
# 1              Alabama     8   0.5112   0.0351   0.0151   0.0058   0.0023
# 2               Baylor     5   0.9412   0.5772   0.1278   0.0305   0.0067
# 3   California Baptist    15   0.0320   0.0136   0.0049   0.0019   0.0008
# 4          Chattanooga    14   0.0729   0.0226   0.0071   0.0027   0.0011
# ..                 ...   ...      ...      ...      ...      ...      ...
# 59                 USC     1   0.9674   0.8767   0.7212   0.3971   0.0898
# 60                Utah     5   0.8490   0.3177   0.0555   0.0145   0.0039
# 61          Vanderbilt    12   0.0829   0.0248   0.0076   0.0033   0.0014
# 62       Virginia Tech     4   0.8706   0.3668   0.0691   0.0228   0.0065
# 63       West Virginia     8   0.5717   0.0206   0.0098   0.0041   0.0020
#
#     Round 6
# 0    0.0005
# 1    0.0010
# 2    0.0022
# 3    0.0004
# 4    0.0006
# ..      ...
# 59   0.0303
# 60   0.0015
# 61   0.0008
# 62   0.0034
# 63   0.0011
#
# [64 rows x 8 columns]

# %% [markdown]
# Fix play-ins

# %%
df.loc[df['Team'].str.contains('/', regex=False), :]
# Out:
#         Team  Seed  Round 1  Round 2  Round 3  Round 4  Round 5  Round 6
# 0   AUB/ARIZ    11   0.1524   0.0182   0.0066   0.0027   0.0011   0.0005
# 17    HC/UTM    16   0.0167   0.0078   0.0039   0.0020   0.0009   0.0003

# %%
df.loc[df['Team'] == 'AUB/ARIZ', 'Team'] = 'Arizona'
df.loc[df['Team'] == 'HC/UTM', 'Team'] = 'UT Martin'

df.loc[df['Team'].str.contains('/', regex=False), :]
# Out:
# Empty DataFrame
# Columns: [Team, Seed, Round 1, Round 2, Round 3, Round 4, Round 5, Round 6]
# Index: []

# %% [markdown]
# Map with Kaggle data

# %%
df_seeds = pd.read_csv(r'..\data\unprocessed\kaggle\WNCAATourneySeeds.csv')

df_seeds = df_seeds.loc[df_seeds['Season'] == season, :].reset_index(drop=True)

df_seeds.insert(2, 'Play In', df_seeds['Seed'].str.endswith(('a', 'b')))
df_seeds.insert(2, 'Region', df_seeds['Seed'].str[0])
df_seeds['Seed'] = df_seeds['Seed'].str.extract('(\d+)').astype(int)

df_seeds
# Out:
#     Season  Seed Region  Play In  TeamID
# 0     2024     1      W    False    3376
# 1     2024     2      W    False    3323
# 2     2024     3      W    False    3333
# 3     2024     4      W    False    3231
# 4     2024     5      W    False    3328
# ..     ...   ...    ...      ...     ...
# 63    2024    12      Z     True    3435
# 64    2024    13      Z    False    3267
# 65    2024    14      Z    False    3238
# 66    2024    15      Z    False    3263
# 67    2024    16      Z    False    3394
#
# [68 rows x 5 columns]

# %%
df_spellings = pd.read_csv(
    r'..\data\unprocessed\kaggle\WTeamSpellings.csv', 
    encoding='cp1252'  # fixes issue with fancy quotes
)

# df_spellings.loc[df_spellings.shape[0]] = ['fdu', 1192]
# df_spellings.loc[df_spellings.shape[0]] = ['sdsu', 1361]
# df_spellings.loc[df_spellings.shape[0]] = ['csu', 1161]

df_spellings
# Out:
#         TeamNameSpelling  TeamID
# 0       a&m-corpus chris    3394
# 1     a&m-corpus christi    3394
# 2            abilene chr    3101
# 3      abilene christian    3101
# 4      abilene-christian    3101
# ...                  ...     ...
# 1153       youngstown st    3464
# 1154      youngstown st.    3464
# 1155    youngstown state    3464
# 1156       youngstown-st    3464
# 1157    youngstown-state    3464
#
# [1158 rows x 2 columns]

# %%
df_spellings = pd.merge(
    df_spellings,
    df_seeds[['TeamID', 'Seed']],
    how='inner',
    on=['TeamID']
)

df_spellings
# Out:
#        TeamNameSpelling  TeamID  Seed
# 0      a&m-corpus chris    3394    16
# 1    a&m-corpus christi    3394    16
# 2       am-corpus-chris    3394    16
# 3                 tam c    3394    16
# 4        tam c. christi    3394    16
# ..                  ...     ...   ...
# 166          vanderbilt    3435    12
# 167       virginia tech    3439     4
# 168       virginia-tech    3439     4
# 169       west virginia    3452     8
# 170       west-virginia    3452     8
#
# [171 rows x 3 columns]

# %%
from fuzzywuzzy.fuzz import token_sort_ratio
from fuzzywuzzy import process
from tqdm.autonotebook import tqdm

team_spellings = df_spellings['TeamNameSpelling'].unique()
yahoo_teams = df.loc[~df['Team'].str.contains('^playin', regex=True), 'Team'].unique()

df_match = pd.DataFrame(
    [
        [
            yahoo_team,
            *process.extract(
                yahoo_team,
                team_spellings,
                scorer=token_sort_ratio,
                limit=1
            )[0][:2]
        ] for yahoo_team in tqdm(yahoo_teams)
    ],
    columns=['Yahoo Team', 'Team Spelling', 'Match Score']
).sort_values('Match Score', ignore_index=True)

df_match.head(25)
# Out:
# C:\Users\mhugh\AppData\Local\Temp\ipykernel_10236\794795546.py:3: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
#   0%|          | 0/64 [00:00<?, ?it/s]
#                   Yahoo Team             Team Spelling  Match Score
# 0                N. Carolina            north carolina           83
# 1             Fla Gulf Coast             fl gulf coast           96
# 2                    Arizona                   arizona          100
# 3                Mississippi               mississippi          100
# 4                 N.C. State                n.c. state          100
# 5                   Nebraska                  nebraska          100
# 6                Norfolk St.                norfolk st          100
# 7                 Notre Dame                notre dame          100
# 8                   Ohio St.                   ohio st          100
# 9                   Oklahoma                  oklahoma          100
# 10                Oregon St.                 oregon st          100
# 11                  Portland                  portland          100
# 12              Presbyterian              presbyterian          100
# 13                 Princeton                 princeton          100
# 14                      Rice                      rice          100
# 15                  Richmond                  richmond          100
# 16             S. Dakota St.               s dakota st          100
# 17            South Carolina            south carolina          100
# 18                  Stanford                  stanford          100
# 19                  Syracuse                  syracuse          100
# 20                 Tennessee                 tennessee          100
# 21                     Texas                     texas          100
# 22                 Texas A&M                 texas a&m          100
# 23  Texas A&M-Corpus Christi  texas a&m-corpus christi          100
# 24                 UC Irvine                 uc irvine          100

# %%
yahoo_to_spelling = dict(zip(df_match['Yahoo Team'], df_match['Team Spelling']))
spelling_to_id = dict(zip(df_spellings['TeamNameSpelling'], df_spellings['TeamID']))

df.insert(1, 'TeamID', df['Team'].map(yahoo_to_spelling).map(spelling_to_id))

df
# Out:
#                   Team  TeamID  Seed  Round 1  Round 2  Round 3  Round 4  \
# 0              Arizona    3112    11   0.1524   0.0182   0.0066   0.0027
# 1              Alabama    3104     8   0.5112   0.0351   0.0151   0.0058
# 2               Baylor    3124     5   0.9412   0.5772   0.1278   0.0305
# 3   California Baptist    3465    15   0.0320   0.0136   0.0049   0.0019
# 4          Chattanooga    3151    14   0.0729   0.0226   0.0071   0.0027
# ..                 ...     ...   ...      ...      ...      ...      ...
# 59                 USC    3425     1   0.9674   0.8767   0.7212   0.3971
# 60                Utah    3428     5   0.8490   0.3177   0.0555   0.0145
# 61          Vanderbilt    3435    12   0.0829   0.0248   0.0076   0.0033
# 62       Virginia Tech    3439     4   0.8706   0.3668   0.0691   0.0228
# 63       West Virginia    3452     8   0.5717   0.0206   0.0098   0.0041
#
#     Round 5  Round 6
# 0    0.0011   0.0005
# 1    0.0023   0.0010
# 2    0.0067   0.0022
# 3    0.0008   0.0004
# 4    0.0011   0.0006
# ..      ...      ...
# 59   0.0898   0.0303
# 60   0.0039   0.0015
# 61   0.0014   0.0008
# 62   0.0065   0.0034
# 63   0.0020   0.0011
#
# [64 rows x 9 columns]

# %%
import numpy as np

id_to_playin = dict(zip(df_seeds['TeamID'], df_seeds['Play In']))
id_to_playin[np.nan] = True

df.insert(3, 'Play In', df['TeamID'].map(id_to_playin))

df
# Out:
#                   Team  TeamID  Seed  Play In  Round 1  Round 2  Round 3  \
# 0              Arizona    3112    11     True   0.1524   0.0182   0.0066
# 1              Alabama    3104     8    False   0.5112   0.0351   0.0151
# 2               Baylor    3124     5    False   0.9412   0.5772   0.1278
# 3   California Baptist    3465    15    False   0.0320   0.0136   0.0049
# 4          Chattanooga    3151    14    False   0.0729   0.0226   0.0071
# ..                 ...     ...   ...      ...      ...      ...      ...
# 59                 USC    3425     1    False   0.9674   0.8767   0.7212
# 60                Utah    3428     5    False   0.8490   0.3177   0.0555
# 61          Vanderbilt    3435    12     True   0.0829   0.0248   0.0076
# 62       Virginia Tech    3439     4    False   0.8706   0.3668   0.0691
# 63       West Virginia    3452     8    False   0.5717   0.0206   0.0098
#
#     Round 4  Round 5  Round 6
# 0    0.0027   0.0011   0.0005
# 1    0.0058   0.0023   0.0010
# 2    0.0305   0.0067   0.0022
# 3    0.0019   0.0008   0.0004
# 4    0.0027   0.0011   0.0006
# ..      ...      ...      ...
# 59   0.3971   0.0898   0.0303
# 60   0.0145   0.0039   0.0015
# 61   0.0033   0.0014   0.0008
# 62   0.0228   0.0065   0.0034
# 63   0.0041   0.0020   0.0011
#
# [64 rows x 10 columns]

# %%
id_to_region = dict(zip(df_seeds['TeamID'], df_seeds['Region']))

df.insert(3, 'Region', df['TeamID'].map(id_to_region))

df
# Out:
#                   Team  TeamID  Seed Region  Play In  Round 1  Round 2  \
# 0              Arizona    3112    11      Z     True   0.1524   0.0182
# 1              Alabama    3104     8      X    False   0.5112   0.0351
# 2               Baylor    3124     5      Z    False   0.9412   0.5772
# 3   California Baptist    3465    15      Y    False   0.0320   0.0136
# 4          Chattanooga    3151    14      X    False   0.0729   0.0226
# ..                 ...     ...   ...    ...      ...      ...      ...
# 59                 USC    3425     1      Z    False   0.9674   0.8767
# 60                Utah    3428     5      X    False   0.8490   0.3177
# 61          Vanderbilt    3435    12      Z     True   0.0829   0.0248
# 62       Virginia Tech    3439     4      Z    False   0.8706   0.3668
# 63       West Virginia    3452     8      Y    False   0.5717   0.0206
#
#     Round 3  Round 4  Round 5  Round 6
# 0    0.0066   0.0027   0.0011   0.0005
# 1    0.0151   0.0058   0.0023   0.0010
# 2    0.1278   0.0305   0.0067   0.0022
# 3    0.0049   0.0019   0.0008   0.0004
# 4    0.0071   0.0027   0.0011   0.0006
# ..      ...      ...      ...      ...
# 59   0.7212   0.3971   0.0898   0.0303
# 60   0.0555   0.0145   0.0039   0.0015
# 61   0.0076   0.0033   0.0014   0.0008
# 62   0.0691   0.0228   0.0065   0.0034
# 63   0.0098   0.0041   0.0020   0.0011
#
# [64 rows x 11 columns]

# %%
df.loc[df['Region'].isna(), :]
# Out:
# Empty DataFrame
# Columns: [Team, TeamID, Seed, Region, Play In, Round 1, Round 2, Round 3, Round 4, Round 5, Round 6]
# Index: []

# %% [markdown]
# Redistribute play-in probabilities to the teams that won

# %% [markdown]
# Unfortunately, it is unclear which play-in game the probabilities are from outside of the seeding, so I will split it evenly

# %%
# for seed in df.loc[df['Play In'], 'Seed'].unique():
#     df.loc[
#         (~df['Team'].str.contains('^playin', regex=True)) & 
#         (df['Seed'] == seed) &
#         (df['Play In']), 
#         [f'Round {i}' for i in range(1, 7)]
#     ] += df.loc[
#         (df['Team'].str.contains('^playin', regex=True)) & 
#         (df['Seed'] == seed) &
#         (df['Play In']), 
#         [f'Round {i}' for i in range(1, 7)]
#     ].mean(axis=0)

# df = df.loc[
#     ~df['Team'].str.contains('^playin', regex=True), 
#     :
# ].reset_index(drop=True)

# df['TeamID'] = df['TeamID'].astype(int)

# df.loc[df['Play In'], :]

# %% [markdown]
# Redistribute percentages to account for rounding inaccuracies

# %%
# for i in range(1, 7):
#     df[f'Round {i}'] = df[f'Round {i}'] / df[f'Round {i}'].sum() * 2**(6 - i)

# df

# %%
df.sum()
# Out:
# Team       ArizonaAlabamaBaylorCalifornia BaptistChattano...
# TeamID                                                211005
# Seed                                                     544
# Region     ZXZYXYZYYXZWWWXXXYWYXZZYWYYZWZXZWYWWXWXWZWWYWY...
# Play In                                                    4
# Round 1                                              31.9061
# Round 2                                              15.9563
# Round 3                                               7.9779
# Round 4                                               3.9889
# Round 5                                               1.9991
# Round 6                                               1.0007
# dtype: object

# %%
df.insert(df.columns.get_loc('Seed'), 'Region Seed', df['Region'] + df['Seed'].astype(str).str.zfill(2))

df
# Out:
#                   Team  TeamID Region Seed  Seed Region  Play In  Round 1  \
# 0              Arizona    3112         Z11    11      Z     True   0.1524
# 1              Alabama    3104         X08     8      X    False   0.5112
# 2               Baylor    3124         Z05     5      Z    False   0.9412
# 3   California Baptist    3465         Y15    15      Y    False   0.0320
# 4          Chattanooga    3151         X14    14      X    False   0.0729
# ..                 ...     ...         ...   ...    ...      ...      ...
# 59                 USC    3425         Z01     1      Z    False   0.9674
# 60                Utah    3428         X05     5      X    False   0.8490
# 61          Vanderbilt    3435         Z12    12      Z     True   0.0829
# 62       Virginia Tech    3439         Z04     4      Z    False   0.8706
# 63       West Virginia    3452         Y08     8      Y    False   0.5717
#
#     Round 2  Round 3  Round 4  Round 5  Round 6
# 0    0.0182   0.0066   0.0027   0.0011   0.0005
# 1    0.0351   0.0151   0.0058   0.0023   0.0010
# 2    0.5772   0.1278   0.0305   0.0067   0.0022
# 3    0.0136   0.0049   0.0019   0.0008   0.0004
# 4    0.0226   0.0071   0.0027   0.0011   0.0006
# ..      ...      ...      ...      ...      ...
# 59   0.8767   0.7212   0.3971   0.0898   0.0303
# 60   0.3177   0.0555   0.0145   0.0039   0.0015
# 61   0.0248   0.0076   0.0033   0.0014   0.0008
# 62   0.3668   0.0691   0.0228   0.0065   0.0034
# 63   0.0206   0.0098   0.0041   0.0020   0.0011
#
# [64 rows x 12 columns]

# %%
df.to_csv(f'../data/preprocessed/womens_yahoo/{season}_womens_yahoo_picks.csv', index=False)

'Done'
# Out:
# 'Done'
