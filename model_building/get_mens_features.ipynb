# %% [markdown]
# # Team Features

# %% [markdown]
# Compile all feature engineering into a model-ready dataframe.

# %% [markdown]
# ### Previous Tournament Results

# %%
import pandas as pd

pd.set_option('display.max_columns', 100)

df = pd.read_csv(r'..\data\preprocessed\kaggle\tournament_results.csv')

df = df.loc[~df['Season'].isin([2020, 2024]), :].reset_index(drop=True)

df
# Out:
#       Season  TeamID              Team  Past Year Tournament Result  \
# 0       2012    1101       Abilene Chr                         -1.0
# 1       2012    1102         Air Force                         -1.0
# 2       2012    1103             Akron                          0.0
# 3       2012    1104           Alabama                         -1.0
# 4       2012    1105       Alabama A&M                         -1.0
# ...      ...     ...               ...                          ...
# 4153    2023    1474         Queens NC                         -1.0
# 4154    2023    1475  Southern Indiana                         -1.0
# 4155    2023    1476         Stonehill                         -1.0
# 4156    2023    1477   TX A&M Commerce                         -1.0
# 4157    2023    1478          Le Moyne                         -1.0
#
#       Past 4 Years Tournament Results
# 0                                -1.0
# 1                                -1.0
# 2                                -0.5
# 3                                -1.0
# 4                                -1.0
# ...                               ...
# 4153                             -1.0
# 4154                             -1.0
# 4155                             -1.0
# 4156                             -1.0
# 4157                             -1.0
#
# [4158 rows x 5 columns]

# %%
# df = pd.merge(
#     df,
#     df_tournament_results,
#     how='left',
#     on=['Season', 'TeamID', 'Team']
# )

# df

# %% [markdown]
# ### Ordinal Rankings

# %% [markdown]
# Omitted

# %%
# import pandas as pd

# pd.set_option('display.max_columns', 100)

# df = pd.read_csv(r'..\data\preprocessed\kaggle\ordinals.csv')

# df = df.loc[df['Season'] != 2020, :].reset_index(drop=True)

# df

# %% [markdown]
# ### Barttorvik Ratings

# %%
df_barttorvik = pd.read_csv(r'..\data\preprocessed\barttorvik\barttorvik.csv')

df_barttorvik
# Out:
#       Season            TEAM      WIN%  ADJOE  ADJDE  ADJEM  BARTHAG  EFG%  \
# 0       2012        Kentucky  0.941176  119.7   88.5   31.2   0.9702  53.4
# 1       2012        Ohio St.  0.794118  115.5   85.5   30.0   0.9695  52.5
# 2       2012          Kansas  0.818182  114.7   88.1   26.6   0.9542  54.0
# 3       2012    Michigan St.  0.794118  112.7   86.7   26.0   0.9532  52.7
# 4       2012  North Carolina  0.852941  115.8   89.6   26.2   0.9502  50.0
# ...      ...             ...       ...    ...    ...    ...      ...   ...
# 3863    2023     Florida A&M  0.185185   88.2  108.1  -19.9   0.0877  45.0
# 3864    2023           IUPUI  0.100000   94.0  117.2  -23.2   0.0728  49.7
# 3865    2023       Green Bay  0.093750   90.5  114.1  -23.6   0.0651  46.0
# 3866    2023        Hartford  0.080000   88.7  116.7  -28.0   0.0412  47.7
# 3867    2023    LIU Brooklyn  0.037037   86.4  115.6  -29.2   0.0338  45.6
#
#       EFGD%   TOR  TORD   ORB   FTR  FTRD  ADJ T.   WAB
# 0      41.6  17.2  18.1  38.4  40.0  25.6    66.1  11.3
# 1      46.3  17.4  22.5  35.7  37.0  28.6    68.1   7.7
# 2      43.9  19.6  20.7  34.9  41.1  34.3    67.9   8.2
# 3      43.0  19.8  19.7  37.2  39.0  34.2    66.1   8.6
# 4      45.1  16.2  18.5  40.5  38.1  22.0    72.7   8.3
# ...     ...   ...   ...   ...   ...   ...     ...   ...
# 3863   51.1  24.0  18.0  27.6  31.4  44.6    65.8 -16.3
# 3864   55.0  23.2  16.7  29.0  32.2  36.0    67.8 -22.5
# 3865   54.8  21.1  16.1  21.7  31.5  31.6    65.9 -23.1
# 3866   55.4  22.7  17.6  25.2  24.1  27.7    66.2 -20.0
# 3867   55.1  22.7  16.7  24.7  31.7  32.1    73.3 -21.3
#
# [3868 rows x 16 columns]

# %%
df_spellings = pd.read_csv(
    r'..\data\unprocessed\kaggle\MTeamSpellings.csv', 
    encoding='cp1252'  # fixes issue with fancy quotes
)

df_spellings.loc[df_spellings.shape[0]] = ['fdu', 1192]

df_spellings
# Out:
#         TeamNameSpelling  TeamID
# 0       a&m-corpus chris    1394
# 1     a&m-corpus christi    1394
# 2            abilene chr    1101
# 3      abilene christian    1101
# 4      abilene-christian    1101
# ...                  ...     ...
# 1161      youngstown st.    1464
# 1162    youngstown state    1464
# 1163       youngstown-st    1464
# 1164    youngstown-state    1464
# 1165                 fdu    1192
#
# [1166 rows x 2 columns]

# %%
from fuzzywuzzy.fuzz import token_sort_ratio
from fuzzywuzzy import process
from tqdm.autonotebook import tqdm

team_spellings = df_spellings['TeamNameSpelling'].unique()
barttorvik_teams = df_barttorvik['TEAM'].unique()

df_match = pd.DataFrame(
    [
        [
            barttorvik_team,
            *process.extract(
                barttorvik_team,
                team_spellings,
                scorer=token_sort_ratio,
                limit=1
            )[0][:2]
        ] for barttorvik_team in tqdm(barttorvik_teams)
    ],
    columns=['Barttorvik Team', 'Team Spelling', 'Match Score']
).sort_values('Match Score', ignore_index=True)

df_match.head(25)
# Out:
# C:\Users\mhugh\AppData\Local\Temp\ipykernel_13460\2439321704.py:3: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
#   0%|          | 0/365 [00:00<?, ?it/s]
#            Barttorvik Team             Team Spelling  Match Score
# 0        Houston Christian               houston chr           79
# 1                   Queens                 queens nc           80
# 2               St. Thomas              st thomas mn           86
# 3     UT Rio Grande Valley   texas rio grande valley           88
# 4       Texas A&M Commerce           tx a&m commerce           91
# 5      Cal St. Bakersfield     cal state bakersfield           92
# 6   Southeast Missouri St.  southeast missouri state           93
# 7   Mississippi Valley St.  mississippi valley state           93
# 8   Texas A&M Corpus Chris  texas a&m-corpus christi           96
# 9          Bethune Cookman           bethune-cookman          100
# 10           Southern Utah             southern utah          100
# 11            Morehead St.               morehead st          100
# 12                    Elon                      elon          100
# 13             Chattanooga               chattanooga          100
# 14                   Siena                     siena          100
# 15             Austin Peay               austin peay          100
# 16        Northwestern St.          northwestern st.          100
# 17                Campbell                  campbell          100
# 18              Wright St.                 wright st          100
# 19                     FIU                       fiu          100
# 20            Sacred Heart              sacred heart          100
# 21                    UMKC                      umkc          100
# 22              Texas Tech                texas tech          100
# 23           James Madison             james madison          100
# 24        Central Michigan          central michigan          100

# %%
barttorvik_to_spelling = dict(zip(df_match['Barttorvik Team'], df_match['Team Spelling']))

len(barttorvik_to_spelling)
# Out:
# 365

# %%
spelling_to_id = dict(zip(df_spellings['TeamNameSpelling'], df_spellings['TeamID']))

len(spelling_to_id)
# Out:
# 1166

# %%
df_barttorvik.insert(1, 'TeamID', df_barttorvik['TEAM'].map(barttorvik_to_spelling).map(spelling_to_id))

df_barttorvik
# Out:
#       Season  TeamID            TEAM      WIN%  ADJOE  ADJDE  ADJEM  BARTHAG  \
# 0       2012    1246        Kentucky  0.941176  119.7   88.5   31.2   0.9702
# 1       2012    1326        Ohio St.  0.794118  115.5   85.5   30.0   0.9695
# 2       2012    1242          Kansas  0.818182  114.7   88.1   26.6   0.9542
# 3       2012    1277    Michigan St.  0.794118  112.7   86.7   26.0   0.9532
# 4       2012    1314  North Carolina  0.852941  115.8   89.6   26.2   0.9502
# ...      ...     ...             ...       ...    ...    ...    ...      ...
# 3863    2023    1197     Florida A&M  0.185185   88.2  108.1  -19.9   0.0877
# 3864    2023    1237           IUPUI  0.100000   94.0  117.2  -23.2   0.0728
# 3865    2023    1453       Green Bay  0.093750   90.5  114.1  -23.6   0.0651
# 3866    2023    1216        Hartford  0.080000   88.7  116.7  -28.0   0.0412
# 3867    2023    1254    LIU Brooklyn  0.037037   86.4  115.6  -29.2   0.0338
#
#       EFG%  EFGD%   TOR  TORD   ORB   FTR  FTRD  ADJ T.   WAB
# 0     53.4   41.6  17.2  18.1  38.4  40.0  25.6    66.1  11.3
# 1     52.5   46.3  17.4  22.5  35.7  37.0  28.6    68.1   7.7
# 2     54.0   43.9  19.6  20.7  34.9  41.1  34.3    67.9   8.2
# 3     52.7   43.0  19.8  19.7  37.2  39.0  34.2    66.1   8.6
# 4     50.0   45.1  16.2  18.5  40.5  38.1  22.0    72.7   8.3
# ...    ...    ...   ...   ...   ...   ...   ...     ...   ...
# 3863  45.0   51.1  24.0  18.0  27.6  31.4  44.6    65.8 -16.3
# 3864  49.7   55.0  23.2  16.7  29.0  32.2  36.0    67.8 -22.5
# 3865  46.0   54.8  21.1  16.1  21.7  31.5  31.6    65.9 -23.1
# 3866  47.7   55.4  22.7  17.6  25.2  24.1  27.7    66.2 -20.0
# 3867  45.6   55.1  22.7  16.7  24.7  31.7  32.1    73.3 -21.3
#
# [3868 rows x 17 columns]

# %%
df_barttorvik.loc[df_barttorvik['TeamID'].isna(), :]
# Out:
# Empty DataFrame
# Columns: [Season, TeamID, TEAM, WIN%, ADJOE, ADJDE, ADJEM, BARTHAG, EFG%, EFGD%, TOR, TORD, ORB, FTR, FTRD, ADJ T., WAB]
# Index: []

# %%
df = pd.merge(
    df,
    # df_barttorvik[[
    #     'Season', 
    #     'TeamID',
    #     'WIN%',
    #     'ADJOE',
    #     'ADJDE',
    #     'BARTHAG',
    #     'ADJ T.',
    # ]],
    df_barttorvik.drop(columns=['TEAM']),
    how='left',
    on=['Season', 'TeamID']
)

df
# Out:
#       Season  TeamID              Team  Past Year Tournament Result  \
# 0       2012    1101       Abilene Chr                         -1.0
# 1       2012    1102         Air Force                         -1.0
# 2       2012    1103             Akron                          0.0
# 3       2012    1104           Alabama                         -1.0
# 4       2012    1105       Alabama A&M                         -1.0
# ...      ...     ...               ...                          ...
# 4153    2023    1474         Queens NC                         -1.0
# 4154    2023    1475  Southern Indiana                         -1.0
# 4155    2023    1476         Stonehill                         -1.0
# 4156    2023    1477   TX A&M Commerce                         -1.0
# 4157    2023    1478          Le Moyne                         -1.0
#
#       Past 4 Years Tournament Results      WIN%  ADJOE  ADJDE  ADJEM  BARTHAG  \
# 0                                -1.0       NaN    NaN    NaN    NaN      NaN
# 1                                -1.0  0.407407   98.5  100.0   -1.5   0.4564
# 2                                -0.5  0.636364  105.1   96.9    8.2   0.7161
# 3                                -1.0  0.656250  105.0   88.1   16.9   0.8829
# 4                                -1.0  0.192308   88.4  111.1  -22.7   0.0677
# ...                               ...       ...    ...    ...    ...      ...
# 4153                             -1.0  0.500000  105.6  108.5   -2.9   0.4217
# 4154                             -1.0  0.448276  101.1  110.6   -9.5   0.2621
# 4155                             -1.0  0.433333   94.1  107.1  -13.0   0.1835
# 4156                             -1.0  0.375000   98.6  111.5  -12.9   0.1953
# 4157                             -1.0       NaN    NaN    NaN    NaN      NaN
#
#       EFG%  EFGD%   TOR  TORD   ORB   FTR  FTRD  ADJ T.   WAB
# 0      NaN    NaN   NaN   NaN   NaN   NaN   NaN     NaN   NaN
# 1     51.1   48.4  20.6  21.5  19.8  39.4  38.2    62.3  -7.6
# 2     51.5   46.4  21.0  20.6  34.8  40.0  34.0    67.8  -1.7
# 3     49.0   43.4  20.4  21.4  33.9  36.5  38.6    63.1   1.6
# 4     45.1   49.2  23.9  20.6  30.4  35.5  52.9    67.9 -17.4
# ...    ...    ...   ...   ...   ...   ...   ...     ...   ...
# 4153  51.2   53.0  17.6  15.7  29.7  35.9  25.4    70.6  -9.4
# 4154  50.5   51.8  18.3  16.7  32.6  33.4  40.3    70.1 -12.6
# 4155  50.9   50.2  19.7  19.8  19.1  32.2  27.3    67.4 -12.6
# 4156  52.4   52.8  18.9  17.7  26.5  28.3  37.9    66.3 -15.4
# 4157   NaN    NaN   NaN   NaN   NaN   NaN   NaN     NaN   NaN
#
# [4158 rows x 19 columns]

# %% [markdown]
# ### Barttorvik Previous Seasons

# %%
df_barttorvik_prev = pd.read_csv(r'..\data\preprocessed\barttorvik_full_season\barttorvik_full_season.csv')

df_barttorvik_prev
# Out:
#       Season               TEAM  Past Year BARTHAG  Past 4 Years BARTHAG
# 0       2012  Abilene Christian                NaN                   NaN
# 1       2012          Air Force             0.5782              0.463200
# 2       2012              Akron             0.6049              0.678300
# 3       2012            Alabama             0.8419              0.782050
# 4       2012        Alabama A&M             0.1283              0.102125
# ...      ...                ...                ...                   ...
# 4399    2023         Wright St.             0.4613              0.625775
# 4400    2023            Wyoming             0.7661              0.456400
# 4401    2023             Xavier             0.8204              0.805150
# 4402    2023               Yale             0.5447              0.667467
# 4403    2023     Youngstown St.             0.3366              0.330250
#
# [4404 rows x 4 columns]

# %%
team_spellings = df_spellings['TeamNameSpelling'].unique()
barttorvik_prev_teams = df_barttorvik_prev['TEAM'].unique()

df_match = pd.DataFrame(
    [
        [
            barttorvik_prev_team,
            *process.extract(
                barttorvik_prev_team,
                team_spellings,
                scorer=token_sort_ratio,
                limit=1
            )[0][:2]
        ] for barttorvik_prev_team in tqdm(barttorvik_prev_teams)
    ],
    columns=['Barttorvik Prev Team', 'Team Spelling', 'Match Score']
).sort_values('Match Score', ignore_index=True)

df_match.head(25)
# Out:
#   0%|          | 0/367 [00:00<?, ?it/s]
#       Barttorvik Prev Team             Team Spelling  Match Score
# 0        Houston Christian               houston chr           79
# 1                   Queens                 queens nc           80
# 2               St. Thomas              st thomas mn           86
# 3     UT Rio Grande Valley   texas rio grande valley           88
# 4       Texas A&M Commerce           tx a&m commerce           91
# 5        Winston Salem St.       winston-salem-state           91
# 6      Cal St. Bakersfield     cal state bakersfield           92
# 7   Southeast Missouri St.  southeast missouri state           93
# 8   Mississippi Valley St.  mississippi valley state           93
# 9   Texas A&M Corpus Chris  texas a&m-corpus christi           96
# 10             Santa Clara               santa clara          100
# 11              Seton Hall                seton hall          100
# 12            Rhode Island              rhode island          100
# 13                 Radford                   radford          100
# 14                   Siena                     siena          100
# 15              Quinnipiac                quinnipiac          100
# 16                    Rice                      rice          100
# 17           South Alabama             south alabama          100
# 18              Providence                providence          100
# 19               Princeton                 princeton          100
# 20            Presbyterian              presbyterian          100
# 21        Prairie View A&M          prairie view a&m          100
# 22            Portland St.               portland st          100
# 23                Portland                  portland          100
# 24              Pittsburgh                pittsburgh          100

# %%
barttorvik_prev_to_spelling = dict(zip(df_match['Barttorvik Prev Team'], df_match['Team Spelling']))

df_barttorvik_prev.insert(1, 'TeamID', df_barttorvik_prev['TEAM'].map(barttorvik_prev_to_spelling).map(spelling_to_id))

df_barttorvik_prev
# Out:
#       Season  TeamID               TEAM  Past Year BARTHAG  \
# 0       2012    1101  Abilene Christian                NaN
# 1       2012    1102          Air Force             0.5782
# 2       2012    1103              Akron             0.6049
# 3       2012    1104            Alabama             0.8419
# 4       2012    1105        Alabama A&M             0.1283
# ...      ...     ...                ...                ...
# 4399    2023    1460         Wright St.             0.4613
# 4400    2023    1461            Wyoming             0.7661
# 4401    2023    1462             Xavier             0.8204
# 4402    2023    1463               Yale             0.5447
# 4403    2023    1464     Youngstown St.             0.3366
#
#       Past 4 Years BARTHAG
# 0                      NaN
# 1                 0.463200
# 2                 0.678300
# 3                 0.782050
# 4                 0.102125
# ...                    ...
# 4399              0.625775
# 4400              0.456400
# 4401              0.805150
# 4402              0.667467
# 4403              0.330250
#
# [4404 rows x 5 columns]

# %%
df = pd.merge(
    df,
    df_barttorvik_prev.drop(columns=['TEAM']),
    how='left',
    on=['Season', 'TeamID']
)

df
# Out:
#       Season  TeamID              Team  Past Year Tournament Result  \
# 0       2012    1101       Abilene Chr                         -1.0
# 1       2012    1102         Air Force                         -1.0
# 2       2012    1103             Akron                          0.0
# 3       2012    1104           Alabama                         -1.0
# 4       2012    1105       Alabama A&M                         -1.0
# ...      ...     ...               ...                          ...
# 4164    2023    1474         Queens NC                         -1.0
# 4165    2023    1475  Southern Indiana                         -1.0
# 4166    2023    1476         Stonehill                         -1.0
# 4167    2023    1477   TX A&M Commerce                         -1.0
# 4168    2023    1478          Le Moyne                         -1.0
#
#       Past 4 Years Tournament Results      WIN%  ADJOE  ADJDE  ADJEM  BARTHAG  \
# 0                                -1.0       NaN    NaN    NaN    NaN      NaN
# 1                                -1.0  0.407407   98.5  100.0   -1.5   0.4564
# 2                                -0.5  0.636364  105.1   96.9    8.2   0.7161
# 3                                -1.0  0.656250  105.0   88.1   16.9   0.8829
# 4                                -1.0  0.192308   88.4  111.1  -22.7   0.0677
# ...                               ...       ...    ...    ...    ...      ...
# 4164                             -1.0  0.500000  105.6  108.5   -2.9   0.4217
# 4165                             -1.0  0.448276  101.1  110.6   -9.5   0.2621
# 4166                             -1.0  0.433333   94.1  107.1  -13.0   0.1835
# 4167                             -1.0  0.375000   98.6  111.5  -12.9   0.1953
# 4168                             -1.0       NaN    NaN    NaN    NaN      NaN
#
#       EFG%  EFGD%   TOR  TORD   ORB   FTR  FTRD  ADJ T.   WAB  \
# 0      NaN    NaN   NaN   NaN   NaN   NaN   NaN     NaN   NaN
# 1     51.1   48.4  20.6  21.5  19.8  39.4  38.2    62.3  -7.6
# 2     51.5   46.4  21.0  20.6  34.8  40.0  34.0    67.8  -1.7
# 3     49.0   43.4  20.4  21.4  33.9  36.5  38.6    63.1   1.6
# 4     45.1   49.2  23.9  20.6  30.4  35.5  52.9    67.9 -17.4
# ...    ...    ...   ...   ...   ...   ...   ...     ...   ...
# 4164  51.2   53.0  17.6  15.7  29.7  35.9  25.4    70.6  -9.4
# 4165  50.5   51.8  18.3  16.7  32.6  33.4  40.3    70.1 -12.6
# 4166  50.9   50.2  19.7  19.8  19.1  32.2  27.3    67.4 -12.6
# 4167  52.4   52.8  18.9  17.7  26.5  28.3  37.9    66.3 -15.4
# 4168   NaN    NaN   NaN   NaN   NaN   NaN   NaN     NaN   NaN
#
#       Past Year BARTHAG  Past 4 Years BARTHAG
# 0                   NaN                   NaN
# 1                0.5782              0.463200
# 2                0.6049              0.678300
# 3                0.8419              0.782050
# 4                0.1283              0.102125
# ...                 ...                   ...
# 4164                NaN                   NaN
# 4165                NaN                   NaN
# 4166                NaN                   NaN
# 4167                NaN                   NaN
# 4168                NaN                   NaN
#
# [4169 rows x 21 columns]

# %%
df.loc[df['Past Year BARTHAG'].isna(), :]
# Out:
#       Season  TeamID              Team  Past Year Tournament Result  \
# 0       2012    1101       Abilene Chr                         -1.0
# 8       2012    1109      Alliant Intl                         -1.0
# 17      2012    1118      Armstrong St                         -1.0
# 20      2012    1121           Augusta                         -1.0
# 27      2012    1128     Birmingham So                         -1.0
# ...      ...     ...               ...                          ...
# 4164    2023    1474         Queens NC                         -1.0
# 4165    2023    1475  Southern Indiana                         -1.0
# 4166    2023    1476         Stonehill                         -1.0
# 4167    2023    1477   TX A&M Commerce                         -1.0
# 4168    2023    1478          Le Moyne                         -1.0
#
#       Past 4 Years Tournament Results      WIN%  ADJOE  ADJDE  ADJEM  BARTHAG  \
# 0                                -1.0       NaN    NaN    NaN    NaN      NaN
# 8                                -1.0       NaN    NaN    NaN    NaN      NaN
# 17                               -1.0       NaN    NaN    NaN    NaN      NaN
# 20                               -1.0       NaN    NaN    NaN    NaN      NaN
# 27                               -1.0       NaN    NaN    NaN    NaN      NaN
# ...                               ...       ...    ...    ...    ...      ...
# 4164                             -1.0  0.500000  105.6  108.5   -2.9   0.4217
# 4165                             -1.0  0.448276  101.1  110.6   -9.5   0.2621
# 4166                             -1.0  0.433333   94.1  107.1  -13.0   0.1835
# 4167                             -1.0  0.375000   98.6  111.5  -12.9   0.1953
# 4168                             -1.0       NaN    NaN    NaN    NaN      NaN
#
#       EFG%  EFGD%   TOR  TORD   ORB   FTR  FTRD  ADJ T.   WAB  \
# 0      NaN    NaN   NaN   NaN   NaN   NaN   NaN     NaN   NaN
# 8      NaN    NaN   NaN   NaN   NaN   NaN   NaN     NaN   NaN
# 17     NaN    NaN   NaN   NaN   NaN   NaN   NaN     NaN   NaN
# 20     NaN    NaN   NaN   NaN   NaN   NaN   NaN     NaN   NaN
# 27     NaN    NaN   NaN   NaN   NaN   NaN   NaN     NaN   NaN
# ...    ...    ...   ...   ...   ...   ...   ...     ...   ...
# 4164  51.2   53.0  17.6  15.7  29.7  35.9  25.4    70.6  -9.4
# 4165  50.5   51.8  18.3  16.7  32.6  33.4  40.3    70.1 -12.6
# 4166  50.9   50.2  19.7  19.8  19.1  32.2  27.3    67.4 -12.6
# 4167  52.4   52.8  18.9  17.7  26.5  28.3  37.9    66.3 -15.4
# 4168   NaN    NaN   NaN   NaN   NaN   NaN   NaN     NaN   NaN
#
#       Past Year BARTHAG  Past 4 Years BARTHAG
# 0                   NaN                   NaN
# 8                   NaN                   NaN
# 17                  NaN                   NaN
# 20                  NaN                   NaN
# 27                  NaN                   NaN
# ...                 ...                   ...
# 4164                NaN                   NaN
# 4165                NaN                   NaN
# 4166                NaN                   NaN
# 4167                NaN                   NaN
# 4168                NaN                   NaN
#
# [319 rows x 21 columns]

# %% [markdown]
# ### My Rankings

# %%
df_rankings = pd.concat(
    (
        pd.read_csv(fr'..\data\preprocessed\my_rankings\my_rankings_{season}.csv')
        .assign(Season=season)
        for season in range(2012, 2024) if season != 2020
    ),
    ignore_index=True
)

df_rankings.insert(0, 'Season', df_rankings.pop('Season'))

df_rankings.drop(columns=['Strength'], inplace=True)

df_rankings
# Out:
#       Season                    Team    Rating  Efficiency Margin  \
# 0       2012                Kentucky  3.416144           0.297875
# 1       2012                Syracuse  3.133934           0.247351
# 2       2012          North Carolina  2.990982           0.242541
# 3       2012          Michigan State  2.856820           0.265908
# 4       2012            Murray State  2.808001           0.139555
# ...      ...                     ...       ...                ...
# 3862    2023            Presbyterian -2.195092          -0.150432
# 3863    2023                   IUPUI -2.406697          -0.210480
# 3864    2023          Hartford Hawks -2.518344          -0.260419
# 3865    2023               Green Bay -2.533588          -0.247050
# 3866    2023  Long Island University -2.950123          -0.253077
#
#       Adjusted Offense  Adjusted Defense  Adjusted Tempo
# 0             1.166730          0.868855       66.950603
# 1             1.132201          0.884851       67.141144
# 2             1.124441          0.881900       73.343437
# 3             1.119664          0.853757       66.464932
# 4             1.073767          0.934212       66.784035
# ...                ...               ...             ...
# 3862          0.936036          1.086467       65.320811
# 3863          0.938439          1.148919       67.983313
# 3864          0.880985          1.141404       67.079234
# 3865          0.888355          1.135405       66.383482
# 3866          0.874157          1.127234       73.351464
#
# [3867 rows x 7 columns]

# %%
my_teams = df_rankings['Team'].unique()

df_match = pd.DataFrame(
    [
        [
            my_team,
            *process.extract(
                my_team,
                team_spellings,
                scorer=token_sort_ratio,
                limit=1
            )[0][:2]
        ] for my_team in tqdm(my_teams)
    ],
    columns=['My Team', 'Team Spelling', 'Match Score']
).sort_values('Match Score', ignore_index=True)

df_match.head(25)
# Out:
#   0%|          | 0/364 [00:00<?, ?it/s]
#                       My Team             Team Spelling  Match Score
# 0              Hartford Hawks                  hartford           73
# 1   St. Francis (NY) Terriers           st francis (ny)           74
# 2           Houston Christian               houston chr           79
# 3       Savannah State Tigers            savannah state           80
# 4                  St. Thomas              st thomas mn           86
# 5                 Kansas City            mo kansas city           88
# 6          Texas A&M-Commerce           tx a&m commerce           91
# 7           Appalachian State         appalachian state          100
# 8               Arizona State             arizona state          100
# 9                North Dakota              north dakota          100
# 10                       Elon                      elon          100
# 11             UNC Wilmington            unc wilmington          100
# 12                    Fordham                   fordham          100
# 13      Cal State Bakersfield     cal state bakersfield          100
# 14           Florida Atlantic          florida atlantic          100
# 15             Texas Southern            texas southern          100
# 16   Southeast Missouri State  southeast missouri state          100
# 17            Bethune-Cookman           bethune-cookman          100
# 18                     Marist                    marist          100
# 19                  San Diego                 san diego          100
# 20                     Furman                    furman          100
# 21           Eastern Michigan          eastern michigan          100
# 22              Southern Utah             southern utah          100
# 23                 Miami (OH)                miami (oh)          100
# 24          Southern Illinois         southern illinois          100

# %%
ranking_to_spelling = dict(zip(df_match['My Team'], df_match['Team Spelling']))

len(ranking_to_spelling)
# Out:
# 364

# %%
df_rankings.insert(1, 'TeamID', df_rankings['Team'].map(ranking_to_spelling).map(spelling_to_id))

df_rankings
# Out:
#       Season  TeamID                    Team    Rating  Efficiency Margin  \
# 0       2012    1246                Kentucky  3.416144           0.297875
# 1       2012    1393                Syracuse  3.133934           0.247351
# 2       2012    1314          North Carolina  2.990982           0.242541
# 3       2012    1277          Michigan State  2.856820           0.265908
# 4       2012    1293            Murray State  2.808001           0.139555
# ...      ...     ...                     ...       ...                ...
# 3862    2023    1342            Presbyterian -2.195092          -0.150432
# 3863    2023    1237                   IUPUI -2.406697          -0.210480
# 3864    2023    1216          Hartford Hawks -2.518344          -0.260419
# 3865    2023    1453               Green Bay -2.533588          -0.247050
# 3866    2023    1254  Long Island University -2.950123          -0.253077
#
#       Adjusted Offense  Adjusted Defense  Adjusted Tempo
# 0             1.166730          0.868855       66.950603
# 1             1.132201          0.884851       67.141144
# 2             1.124441          0.881900       73.343437
# 3             1.119664          0.853757       66.464932
# 4             1.073767          0.934212       66.784035
# ...                ...               ...             ...
# 3862          0.936036          1.086467       65.320811
# 3863          0.938439          1.148919       67.983313
# 3864          0.880985          1.141404       67.079234
# 3865          0.888355          1.135405       66.383482
# 3866          0.874157          1.127234       73.351464
#
# [3867 rows x 8 columns]

# %%
df_rankings.loc[df_rankings['TeamID'].isna(), :]
# Out:
# Empty DataFrame
# Columns: [Season, TeamID, Team, Rating, Efficiency Margin, Adjusted Offense, Adjusted Defense, Adjusted Tempo]
# Index: []

# %%
df = pd.merge(
    df,
    df_rankings.drop(columns=['Team']),
    how='left',
    on=['Season', 'TeamID']
)

df
# Out:
#       Season  TeamID              Team  Past Year Tournament Result  \
# 0       2012    1101       Abilene Chr                         -1.0
# 1       2012    1102         Air Force                         -1.0
# 2       2012    1103             Akron                          0.0
# 3       2012    1104           Alabama                         -1.0
# 4       2012    1105       Alabama A&M                         -1.0
# ...      ...     ...               ...                          ...
# 4164    2023    1474         Queens NC                         -1.0
# 4165    2023    1475  Southern Indiana                         -1.0
# 4166    2023    1476         Stonehill                         -1.0
# 4167    2023    1477   TX A&M Commerce                         -1.0
# 4168    2023    1478          Le Moyne                         -1.0
#
#       Past 4 Years Tournament Results      WIN%  ADJOE  ADJDE  ADJEM  BARTHAG  \
# 0                                -1.0       NaN    NaN    NaN    NaN      NaN
# 1                                -1.0  0.407407   98.5  100.0   -1.5   0.4564
# 2                                -0.5  0.636364  105.1   96.9    8.2   0.7161
# 3                                -1.0  0.656250  105.0   88.1   16.9   0.8829
# 4                                -1.0  0.192308   88.4  111.1  -22.7   0.0677
# ...                               ...       ...    ...    ...    ...      ...
# 4164                             -1.0  0.500000  105.6  108.5   -2.9   0.4217
# 4165                             -1.0  0.448276  101.1  110.6   -9.5   0.2621
# 4166                             -1.0  0.433333   94.1  107.1  -13.0   0.1835
# 4167                             -1.0  0.375000   98.6  111.5  -12.9   0.1953
# 4168                             -1.0       NaN    NaN    NaN    NaN      NaN
#
#       EFG%  EFGD%   TOR  TORD   ORB   FTR  FTRD  ADJ T.   WAB  \
# 0      NaN    NaN   NaN   NaN   NaN   NaN   NaN     NaN   NaN
# 1     51.1   48.4  20.6  21.5  19.8  39.4  38.2    62.3  -7.6
# 2     51.5   46.4  21.0  20.6  34.8  40.0  34.0    67.8  -1.7
# 3     49.0   43.4  20.4  21.4  33.9  36.5  38.6    63.1   1.6
# 4     45.1   49.2  23.9  20.6  30.4  35.5  52.9    67.9 -17.4
# ...    ...    ...   ...   ...   ...   ...   ...     ...   ...
# 4164  51.2   53.0  17.6  15.7  29.7  35.9  25.4    70.6  -9.4
# 4165  50.5   51.8  18.3  16.7  32.6  33.4  40.3    70.1 -12.6
# 4166  50.9   50.2  19.7  19.8  19.1  32.2  27.3    67.4 -12.6
# 4167  52.4   52.8  18.9  17.7  26.5  28.3  37.9    66.3 -15.4
# 4168   NaN    NaN   NaN   NaN   NaN   NaN   NaN     NaN   NaN
#
#       Past Year BARTHAG  Past 4 Years BARTHAG    Rating  Efficiency Margin  \
# 0                   NaN                   NaN       NaN                NaN
# 1                0.5782              0.463200 -0.152520          -0.020081
# 2                0.6049              0.678300  1.341049           0.095792
# 3                0.8419              0.782050  1.585085           0.154575
# 4                0.1283              0.102125 -2.376490          -0.191533
# ...                 ...                   ...       ...                ...
# 4164                NaN                   NaN  0.053745          -0.017864
# 4165                NaN                   NaN -0.608620          -0.058034
# 4166                NaN                   NaN -0.931737          -0.112451
# 4167                NaN                   NaN -1.093229          -0.094676
# 4168                NaN                   NaN       NaN                NaN
#
#       Adjusted Offense  Adjusted Defense  Adjusted Tempo
# 0                  NaN               NaN             NaN
# 1             0.979958          1.000039       62.835529
# 2             1.045707          0.949915       68.483451
# 3             1.034248          0.879673       63.967881
# 4             0.890904          1.082437       68.157471
# ...                ...               ...             ...
# 4164          1.058141          1.076004       70.263382
# 4165          1.020948          1.078982       70.370070
# 4166          0.948106          1.060557       67.604692
# 4167          0.998594          1.093269       66.657934
# 4168               NaN               NaN             NaN
#
# [4169 rows x 26 columns]

# %%
df.loc[df['Rating'].isna(), :]
# Out:
#       Season  TeamID           Team  Past Year Tournament Result  \
# 0       2012    1101    Abilene Chr                         -1.0
# 8       2012    1109   Alliant Intl                         -1.0
# 17      2012    1118   Armstrong St                         -1.0
# 20      2012    1121        Augusta                         -1.0
# 27      2012    1128  Birmingham So                         -1.0
# ...      ...     ...            ...                          ...
# 4056    2023    1366    Savannah St                         -1.0
# 4122    2023    1432          Utica                         -1.0
# 4135    2023    1445     W Salem St                         -1.0
# 4136    2023    1446    W Texas A&M                         -1.0
# 4168    2023    1478       Le Moyne                         -1.0
#
#       Past 4 Years Tournament Results  WIN%  ADJOE  ADJDE  ADJEM  BARTHAG  \
# 0                                -1.0   NaN    NaN    NaN    NaN      NaN
# 8                                -1.0   NaN    NaN    NaN    NaN      NaN
# 17                               -1.0   NaN    NaN    NaN    NaN      NaN
# 20                               -1.0   NaN    NaN    NaN    NaN      NaN
# 27                               -1.0   NaN    NaN    NaN    NaN      NaN
# ...                               ...   ...    ...    ...    ...      ...
# 4056                             -1.0   NaN    NaN    NaN    NaN      NaN
# 4122                             -1.0   NaN    NaN    NaN    NaN      NaN
# 4135                             -1.0   NaN    NaN    NaN    NaN      NaN
# 4136                             -1.0   NaN    NaN    NaN    NaN      NaN
# 4168                             -1.0   NaN    NaN    NaN    NaN      NaN
#
#       EFG%  EFGD%  TOR  TORD  ORB  FTR  FTRD  ADJ T.  WAB  Past Year BARTHAG  \
# 0      NaN    NaN  NaN   NaN  NaN  NaN   NaN     NaN  NaN                NaN
# 8      NaN    NaN  NaN   NaN  NaN  NaN   NaN     NaN  NaN                NaN
# 17     NaN    NaN  NaN   NaN  NaN  NaN   NaN     NaN  NaN                NaN
# 20     NaN    NaN  NaN   NaN  NaN  NaN   NaN     NaN  NaN                NaN
# 27     NaN    NaN  NaN   NaN  NaN  NaN   NaN     NaN  NaN                NaN
# ...    ...    ...  ...   ...  ...  ...   ...     ...  ...                ...
# 4056   NaN    NaN  NaN   NaN  NaN  NaN   NaN     NaN  NaN                NaN
# 4122   NaN    NaN  NaN   NaN  NaN  NaN   NaN     NaN  NaN                NaN
# 4135   NaN    NaN  NaN   NaN  NaN  NaN   NaN     NaN  NaN                NaN
# 4136   NaN    NaN  NaN   NaN  NaN  NaN   NaN     NaN  NaN                NaN
# 4168   NaN    NaN  NaN   NaN  NaN  NaN   NaN     NaN  NaN                NaN
#
#       Past 4 Years BARTHAG  Rating  Efficiency Margin  Adjusted Offense  \
# 0                      NaN     NaN                NaN               NaN
# 8                      NaN     NaN                NaN               NaN
# 17                     NaN     NaN                NaN               NaN
# 20                     NaN     NaN                NaN               NaN
# 27                     NaN     NaN                NaN               NaN
# ...                    ...     ...                ...               ...
# 4056                   NaN     NaN                NaN               NaN
# 4122                   NaN     NaN                NaN               NaN
# 4135                   NaN     NaN                NaN               NaN
# 4136                   NaN     NaN                NaN               NaN
# 4168                   NaN     NaN                NaN               NaN
#
#       Adjusted Defense  Adjusted Tempo
# 0                  NaN             NaN
# 8                  NaN             NaN
# 17                 NaN             NaN
# 20                 NaN             NaN
# 27                 NaN             NaN
# ...                ...             ...
# 4056               NaN             NaN
# 4122               NaN             NaN
# 4135               NaN             NaN
# 4136               NaN             NaN
# 4168               NaN             NaN
#
# [291 rows x 26 columns]

# %% [markdown]
# ### Starters

# %%
df_starters = pd.concat(
    (
        pd.read_csv(fr'..\data\preprocessed\starters\starters_{season}.csv')
        .assign(Season=season)
        for season in range(2012, 2024) if season != 2020
    ),
    ignore_index=True
)

df_starters.insert(0, 'Season', df_starters.pop('Season'))

df_starters.rename(columns={'Rating': 'Starters'}, inplace=True)

df_starters
# Out:
#       Season                    Team  Starters
# 0       2012            Murray State  0.566137
# 1       2012          Michigan State  0.544399
# 2       2012                    Duke  0.525030
# 3       2012           Wichita State  0.522023
# 4       2012                Kentucky  0.521597
# ...      ...                     ...       ...
# 3862    2023       Houston Christian -0.374878
# 3863    2023            Presbyterian -0.390325
# 3864    2023  Long Island University -0.401581
# 3865    2023                Hartford -0.433945
# 3866    2023               Green Bay -0.468287
#
# [3867 rows x 3 columns]

# %%
starters_teams = df_starters['Team'].unique()

df_match = pd.DataFrame(
    [
        [
            starters_team,
            *process.extract(
                starters_team,
                team_spellings,
                scorer=token_sort_ratio,
                limit=1
            )[0][:2]
        ] for starters_team in tqdm(starters_teams)
    ],
    columns=['Starters Team', 'Team Spelling', 'Match Score']
).sort_values('Match Score', ignore_index=True)

df_match.head(25)
# Out:
#   0%|          | 0/364 [00:00<?, ?it/s]
#                Starters Team             Team Spelling  Match Score
# 0          Houston Christian               houston chr           79
# 1                 St. Thomas              st thomas mn           86
# 2                Kansas City            mo kansas city           88
# 3         Texas A&M-Commerce           tx a&m commerce           91
# 4   Southeast Missouri State  southeast missouri state          100
# 5                  Louisiana                 louisiana          100
# 6          Appalachian State         appalachian state          100
# 7                   Southern                  southern          100
# 8     Southeastern Louisiana    southeastern louisiana          100
# 9               North Dakota              north dakota          100
# 10              Jacksonville              jacksonville          100
# 11              Morgan State              morgan state          100
# 12          Eastern Kentucky          eastern kentucky          100
# 13              Northeastern              northeastern          100
# 14              Coppin State              coppin state          100
# 15                   Seattle                   seattle          100
# 16              Rhode Island              rhode island          100
# 17                  Monmouth                  monmouth          100
# 18          Western Illinois          western illinois          100
# 19                    Tulane                    tulane          100
# 20                    Furman                    furman          100
# 21              Presbyterian              presbyterian          100
# 22                 UC Irvine                 uc irvine          100
# 23               Texas State               texas state          100
# 24                  Lipscomb                  lipscomb          100

# %%
starters_to_spelling = dict(zip(df_match['Starters Team'], df_match['Team Spelling']))

len(starters_to_spelling)
# Out:
# 364

# %%
df_starters.insert(1, 'TeamID', df_starters['Team'].map(starters_to_spelling).map(spelling_to_id))

df_starters
# Out:
#       Season  TeamID                    Team  Starters
# 0       2012    1293            Murray State  0.566137
# 1       2012    1277          Michigan State  0.544399
# 2       2012    1181                    Duke  0.525030
# 3       2012    1455           Wichita State  0.522023
# 4       2012    1246                Kentucky  0.521597
# ...      ...     ...                     ...       ...
# 3862    2023    1223       Houston Christian -0.374878
# 3863    2023    1342            Presbyterian -0.390325
# 3864    2023    1254  Long Island University -0.401581
# 3865    2023    1216                Hartford -0.433945
# 3866    2023    1453               Green Bay -0.468287
#
# [3867 rows x 4 columns]

# %%
df_starters.loc[df_starters['TeamID'].isna(), :]
# Out:
# Empty DataFrame
# Columns: [Season, TeamID, Team, Starters]
# Index: []

# %%
df = pd.merge(
    df,
    df_starters.drop(columns=['Team']),
    how='left',
    on=['Season', 'TeamID']
)

df
# Out:
#       Season  TeamID              Team  Past Year Tournament Result  \
# 0       2012    1101       Abilene Chr                         -1.0
# 1       2012    1102         Air Force                         -1.0
# 2       2012    1103             Akron                          0.0
# 3       2012    1104           Alabama                         -1.0
# 4       2012    1105       Alabama A&M                         -1.0
# ...      ...     ...               ...                          ...
# 4164    2023    1474         Queens NC                         -1.0
# 4165    2023    1475  Southern Indiana                         -1.0
# 4166    2023    1476         Stonehill                         -1.0
# 4167    2023    1477   TX A&M Commerce                         -1.0
# 4168    2023    1478          Le Moyne                         -1.0
#
#       Past 4 Years Tournament Results      WIN%  ADJOE  ADJDE  ADJEM  BARTHAG  \
# 0                                -1.0       NaN    NaN    NaN    NaN      NaN
# 1                                -1.0  0.407407   98.5  100.0   -1.5   0.4564
# 2                                -0.5  0.636364  105.1   96.9    8.2   0.7161
# 3                                -1.0  0.656250  105.0   88.1   16.9   0.8829
# 4                                -1.0  0.192308   88.4  111.1  -22.7   0.0677
# ...                               ...       ...    ...    ...    ...      ...
# 4164                             -1.0  0.500000  105.6  108.5   -2.9   0.4217
# 4165                             -1.0  0.448276  101.1  110.6   -9.5   0.2621
# 4166                             -1.0  0.433333   94.1  107.1  -13.0   0.1835
# 4167                             -1.0  0.375000   98.6  111.5  -12.9   0.1953
# 4168                             -1.0       NaN    NaN    NaN    NaN      NaN
#
#       EFG%  EFGD%   TOR  TORD   ORB   FTR  FTRD  ADJ T.   WAB  \
# 0      NaN    NaN   NaN   NaN   NaN   NaN   NaN     NaN   NaN
# 1     51.1   48.4  20.6  21.5  19.8  39.4  38.2    62.3  -7.6
# 2     51.5   46.4  21.0  20.6  34.8  40.0  34.0    67.8  -1.7
# 3     49.0   43.4  20.4  21.4  33.9  36.5  38.6    63.1   1.6
# 4     45.1   49.2  23.9  20.6  30.4  35.5  52.9    67.9 -17.4
# ...    ...    ...   ...   ...   ...   ...   ...     ...   ...
# 4164  51.2   53.0  17.6  15.7  29.7  35.9  25.4    70.6  -9.4
# 4165  50.5   51.8  18.3  16.7  32.6  33.4  40.3    70.1 -12.6
# 4166  50.9   50.2  19.7  19.8  19.1  32.2  27.3    67.4 -12.6
# 4167  52.4   52.8  18.9  17.7  26.5  28.3  37.9    66.3 -15.4
# 4168   NaN    NaN   NaN   NaN   NaN   NaN   NaN     NaN   NaN
#
#       Past Year BARTHAG  Past 4 Years BARTHAG    Rating  Efficiency Margin  \
# 0                   NaN                   NaN       NaN                NaN
# 1                0.5782              0.463200 -0.152520          -0.020081
# 2                0.6049              0.678300  1.341049           0.095792
# 3                0.8419              0.782050  1.585085           0.154575
# 4                0.1283              0.102125 -2.376490          -0.191533
# ...                 ...                   ...       ...                ...
# 4164                NaN                   NaN  0.053745          -0.017864
# 4165                NaN                   NaN -0.608620          -0.058034
# 4166                NaN                   NaN -0.931737          -0.112451
# 4167                NaN                   NaN -1.093229          -0.094676
# 4168                NaN                   NaN       NaN                NaN
#
#       Adjusted Offense  Adjusted Defense  Adjusted Tempo  Starters
# 0                  NaN               NaN             NaN       NaN
# 1             0.979958          1.000039       62.835529 -0.065026
# 2             1.045707          0.949915       68.483451  0.347701
# 3             1.034248          0.879673       63.967881  0.222821
# 4             0.890904          1.082437       68.157471 -0.306213
# ...                ...               ...             ...       ...
# 4164          1.058141          1.076004       70.263382  0.027291
# 4165          1.020948          1.078982       70.370070  0.016206
# 4166          0.948106          1.060557       67.604692 -0.113922
# 4167          0.998594          1.093269       66.657934 -0.159400
# 4168               NaN               NaN             NaN       NaN
#
# [4169 rows x 27 columns]

# %%
df.loc[df['Starters'].isna(), :]
# Out:
#       Season  TeamID           Team  Past Year Tournament Result  \
# 0       2012    1101    Abilene Chr                         -1.0
# 8       2012    1109   Alliant Intl                         -1.0
# 17      2012    1118   Armstrong St                         -1.0
# 20      2012    1121        Augusta                         -1.0
# 27      2012    1128  Birmingham So                         -1.0
# ...      ...     ...            ...                          ...
# 4056    2023    1366    Savannah St                         -1.0
# 4122    2023    1432          Utica                         -1.0
# 4135    2023    1445     W Salem St                         -1.0
# 4136    2023    1446    W Texas A&M                         -1.0
# 4168    2023    1478       Le Moyne                         -1.0
#
#       Past 4 Years Tournament Results  WIN%  ADJOE  ADJDE  ADJEM  BARTHAG  \
# 0                                -1.0   NaN    NaN    NaN    NaN      NaN
# 8                                -1.0   NaN    NaN    NaN    NaN      NaN
# 17                               -1.0   NaN    NaN    NaN    NaN      NaN
# 20                               -1.0   NaN    NaN    NaN    NaN      NaN
# 27                               -1.0   NaN    NaN    NaN    NaN      NaN
# ...                               ...   ...    ...    ...    ...      ...
# 4056                             -1.0   NaN    NaN    NaN    NaN      NaN
# 4122                             -1.0   NaN    NaN    NaN    NaN      NaN
# 4135                             -1.0   NaN    NaN    NaN    NaN      NaN
# 4136                             -1.0   NaN    NaN    NaN    NaN      NaN
# 4168                             -1.0   NaN    NaN    NaN    NaN      NaN
#
#       EFG%  EFGD%  TOR  TORD  ORB  FTR  FTRD  ADJ T.  WAB  Past Year BARTHAG  \
# 0      NaN    NaN  NaN   NaN  NaN  NaN   NaN     NaN  NaN                NaN
# 8      NaN    NaN  NaN   NaN  NaN  NaN   NaN     NaN  NaN                NaN
# 17     NaN    NaN  NaN   NaN  NaN  NaN   NaN     NaN  NaN                NaN
# 20     NaN    NaN  NaN   NaN  NaN  NaN   NaN     NaN  NaN                NaN
# 27     NaN    NaN  NaN   NaN  NaN  NaN   NaN     NaN  NaN                NaN
# ...    ...    ...  ...   ...  ...  ...   ...     ...  ...                ...
# 4056   NaN    NaN  NaN   NaN  NaN  NaN   NaN     NaN  NaN                NaN
# 4122   NaN    NaN  NaN   NaN  NaN  NaN   NaN     NaN  NaN                NaN
# 4135   NaN    NaN  NaN   NaN  NaN  NaN   NaN     NaN  NaN                NaN
# 4136   NaN    NaN  NaN   NaN  NaN  NaN   NaN     NaN  NaN                NaN
# 4168   NaN    NaN  NaN   NaN  NaN  NaN   NaN     NaN  NaN                NaN
#
#       Past 4 Years BARTHAG  Rating  Efficiency Margin  Adjusted Offense  \
# 0                      NaN     NaN                NaN               NaN
# 8                      NaN     NaN                NaN               NaN
# 17                     NaN     NaN                NaN               NaN
# 20                     NaN     NaN                NaN               NaN
# 27                     NaN     NaN                NaN               NaN
# ...                    ...     ...                ...               ...
# 4056                   NaN     NaN                NaN               NaN
# 4122                   NaN     NaN                NaN               NaN
# 4135                   NaN     NaN                NaN               NaN
# 4136                   NaN     NaN                NaN               NaN
# 4168                   NaN     NaN                NaN               NaN
#
#       Adjusted Defense  Adjusted Tempo  Starters
# 0                  NaN             NaN       NaN
# 8                  NaN             NaN       NaN
# 17                 NaN             NaN       NaN
# 20                 NaN             NaN       NaN
# 27                 NaN             NaN       NaN
# ...                ...             ...       ...
# 4056               NaN             NaN       NaN
# 4122               NaN             NaN       NaN
# 4135               NaN             NaN       NaN
# 4136               NaN             NaN       NaN
# 4168               NaN             NaN       NaN
#
# [291 rows x 27 columns]

# %% [markdown]
# ### Strength of Schedule

# %% [markdown]
# Omitted

# %%
# df_sos = pd.read_csv('../data/preprocessed/mens_sos/mens_sos.csv')

# df_sos

# %%
# sos_teams = df_sos['Team'].unique()

# df_match = pd.DataFrame(
#     [
#         [
#             sos_team,
#             *process.extract(
#                 sos_team,
#                 team_spellings,
#                 scorer=token_sort_ratio,
#                 limit=1
#             )[0][:2]
#         ] for sos_team in tqdm(sos_teams)
#     ],
#     columns=['SOS Team', 'Team Spelling', 'Match Score']
# ).sort_values('Match Score', ignore_index=True)

# df_match.head(25)

# %%
# sos_to_spelling = dict(zip(df_match['SOS Team'], df_match['Team Spelling']))

# df_sos.insert(1, 'TeamID', df_sos['Team'].map(sos_to_spelling).map(spelling_to_id))

# df_sos

# %%
# df = pd.merge(
#     df,
#     df_sos.drop(columns=['Team']),
#     how='left',
#     on=['Season', 'TeamID']
# )

# df

# %%
# df.loc[df['0.5 Win'].isna(), :]

# %% [markdown]
# ### Map to Matchups

# %%
df_mod = pd.read_csv(r'..\data\unprocessed\kaggle\MNCAATourneyDetailedResults.csv')[['Season', 'DayNum', 'WTeamID', 'LTeamID']]

df_mod = df_mod.loc[df_mod['Season'] >= 2012, :].reset_index(drop=True)

# fix 2021 dates
df_mod.loc[
    (df_mod['Season'] == 2021) & 
    (df_mod['DayNum'] < 140), 
    'DayNum'
] = df_mod.loc[
    (df_mod['Season'] == 2021) & 
    (df_mod['DayNum'] < 140), 
    'DayNum'
] - 1

df_mod.loc[
    (df_mod['Season'] == 2021) & 
    (df_mod['DayNum'].between(140, 150)), 
    'DayNum'
] = df_mod.loc[
    (df_mod['Season'] == 2021) & 
    (df_mod['DayNum'].between(140, 150)), 
    'DayNum'
] - 2

# get rid of play-in games
df_mod = df_mod.loc[df_mod['DayNum'] > 135, :].reset_index(drop=True)

df_mod
# Out:
#      Season  DayNum  WTeamID  LTeamID
# 0      2012     136     1124     1355
# 1      2012     136     1160     1424
# 2      2012     136     1211     1452
# 3      2012     136     1231     1308
# 4      2012     136     1235     1163
# ..      ...     ...      ...      ...
# 687    2023     146     1274     1400
# 688    2023     146     1361     1166
# 689    2023     152     1163     1274
# 690    2023     152     1361     1194
# 691    2023     154     1163     1361
#
# [692 rows x 4 columns]

# %% [markdown]
# Get round of each game

# %%
df_mod['Round'] = 1
df_mod.loc[df_mod['DayNum'].between(138, 139), 'Round'] = 2
df_mod.loc[df_mod['DayNum'].between(140, 144), 'Round'] = 3
df_mod.loc[df_mod['DayNum'].between(145, 149), 'Round'] = 4
df_mod.loc[df_mod['DayNum'].between(150, 153), 'Round'] = 5
df_mod.loc[df_mod['DayNum'] == 154, 'Round'] = 6

df_mod
# Out:
#      Season  DayNum  WTeamID  LTeamID  Round
# 0      2012     136     1124     1355      1
# 1      2012     136     1160     1424      1
# 2      2012     136     1211     1452      1
# 3      2012     136     1231     1308      1
# 4      2012     136     1235     1163      1
# ..      ...     ...      ...      ...    ...
# 687    2023     146     1274     1400      4
# 688    2023     146     1361     1166      4
# 689    2023     152     1163     1274      5
# 690    2023     152     1361     1194      5
# 691    2023     154     1163     1361      6
#
# [692 rows x 5 columns]

# %%
for season in range(2012, 2024):
    for round_ in range(1, 7):
        if df_mod.loc[(df_mod['Season'] == season) & (df_mod['Round'] == round_), :].shape[0] != 2**(6 - round_):
            print(f"{season}, {round_} : {df_mod.loc[(df_mod['Season'] == season) & (df_mod['Round'] == round_), :].shape[0]}")
# Out:
# 2020, 1 : 0
# 2020, 2 : 0
# 2020, 3 : 0
# 2020, 4 : 0
# 2020, 5 : 0
# 2020, 6 : 0
# 2021, 1 : 31

# %% [markdown]
# Remap to Team A / Team B format

# %%
df_mod = pd.DataFrame({
    'Season': list(df_mod['Season'])*2,
    'Round': list(df_mod['Round'])*2,
    'Result': [1 for _ in range(df_mod.shape[0])] + [-1 for _ in range(df_mod.shape[0])],
    'Team A ID': list(df_mod['WTeamID']) + list(df_mod['LTeamID']),
    'Team B ID': list(df_mod['LTeamID']) + list(df_mod['WTeamID']),
})

df_mod
# Out:
#       Season  Round  Result  Team A ID  Team B ID
# 0       2012      1       1       1124       1355
# 1       2012      1       1       1160       1424
# 2       2012      1       1       1211       1452
# 3       2012      1       1       1231       1308
# 4       2012      1       1       1235       1163
# ...      ...    ...     ...        ...        ...
# 1379    2023      4      -1       1400       1274
# 1380    2023      4      -1       1166       1361
# 1381    2023      5      -1       1274       1163
# 1382    2023      5      -1       1194       1361
# 1383    2023      6      -1       1361       1163
#
# [1384 rows x 5 columns]

# %% [markdown]
# Get Head-to-Head (Omitted)

# %%
# df_h2h = pd.read_csv('../data/preprocessed/men_h2h/men_h2h.csv')

# df_h2h

# %%
# h2h_teams = df_h2h['Team A'].unique()

# df_match = pd.DataFrame(
#     [
#         [
#             h2h_team,
#             *process.extract(
#                 h2h_team,
#                 team_spellings,
#                 scorer=token_sort_ratio,
#                 limit=1
#             )[0][:2]
#         ] for h2h_team in tqdm(h2h_teams)
#     ],
#     columns=['Head to Head Team', 'Team Spelling', 'Match Score']
# ).sort_values('Match Score', ignore_index=True)

# df_match.head(25)

# %%
# h2h_to_spelling = dict(zip(df_match['Head to Head Team'], df_match['Team Spelling']))

# df_h2h.insert(df_h2h.columns.get_loc('Team A'), 'Team A ID', df_h2h['Team A'].map(h2h_to_spelling).map(spelling_to_id))

# df_h2h.insert(df_h2h.columns.get_loc('Team B'), 'Team B ID', df_h2h['Team B'].map(h2h_to_spelling).map(spelling_to_id))

# df_h2h

# %%
# df_mod = pd.merge(
#     df_mod,
#     df_h2h[['Season', 'Team A ID', 'Team B ID', 'Head to Head', 'Common Opps']],
#     how='left',
#     on=['Season', 'Team A ID', 'Team B ID'],
# )

# df_mod

# %% [markdown]
# Get team names

# %%
df_teams = pd.read_csv(r'..\data\unprocessed\kaggle\MTeams.csv')

df_teams
# Out:
#      TeamID          TeamName  FirstD1Season  LastD1Season
# 0      1101       Abilene Chr           2014          2024
# 1      1102         Air Force           1985          2024
# 2      1103             Akron           1985          2024
# 3      1104           Alabama           1985          2024
# 4      1105       Alabama A&M           2000          2024
# ..      ...               ...            ...           ...
# 373    1474         Queens NC           2023          2024
# 374    1475  Southern Indiana           2023          2024
# 375    1476         Stonehill           2023          2024
# 376    1477   TX A&M Commerce           2023          2024
# 377    1478          Le Moyne           2024          2024
#
# [378 rows x 4 columns]

# %%
id_to_team = dict(zip(df_teams['TeamID'], df_teams['TeamName']))

df_mod.insert(df_mod.columns.get_loc('Team A ID') + 1, 'Team A', df_mod['Team A ID'].map(id_to_team))
df_mod.insert(df_mod.columns.get_loc('Team B ID') + 1, 'Team B', df_mod['Team B ID'].map(id_to_team))

df_mod
# Out:
#       Season  Round  Result  Team A ID        Team A  Team B ID         Team B
# 0       2012      1       1       1124        Baylor       1355    S Dakota St
# 1       2012      1       1       1160      Colorado       1424           UNLV
# 2       2012      1       1       1211       Gonzaga       1452  West Virginia
# 3       2012      1       1       1231       Indiana       1308  New Mexico St
# 4       2012      1       1       1235       Iowa St       1163    Connecticut
# ...      ...    ...     ...        ...           ...        ...            ...
# 1379    2023      4      -1       1400         Texas       1274       Miami FL
# 1380    2023      4      -1       1166     Creighton       1361   San Diego St
# 1381    2023      5      -1       1274      Miami FL       1163    Connecticut
# 1382    2023      5      -1       1194   FL Atlantic       1361   San Diego St
# 1383    2023      6      -1       1361  San Diego St       1163    Connecticut
#
# [1384 rows x 7 columns]

# %% [markdown]
# Map features

# %%
team_a_features = pd.merge(
    df_mod[['Season', 'Team A ID']],
    df.drop(columns=['Team']),
    how='left',
    left_on=['Season', 'Team A ID'],
    right_on=['Season', 'TeamID'],
).drop(columns=['Season', 'Team A ID', 'TeamID'])

team_b_features = pd.merge(
    df_mod[['Season', 'Team B ID']],
    df.drop(columns=['Team']),
    how='left',
    left_on=['Season', 'Team B ID'],
    right_on=['Season', 'TeamID'],
).drop(columns=['Season', 'Team B ID', 'TeamID'])

df_features = team_a_features - team_b_features

df_features['Team A ADJOE Team B ADJDE'] = team_a_features['ADJOE'] + team_b_features['ADJDE']
df_features['Team B ADJOE Team A ADJDE'] = team_b_features['ADJOE'] + team_a_features['ADJDE']

df_features['Team A Offense Team B Defense'] = team_a_features['Adjusted Offense'] + team_b_features['Adjusted Defense']
df_features['Team B Offense Team A Defense'] = team_b_features['Adjusted Offense'] + team_a_features['Adjusted Defense']

df_features['Team A BARTHAG'] = team_a_features['BARTHAG']
df_features['Team B BARTHAG'] = team_b_features['BARTHAG']

df_features
# Out:
#       Past Year Tournament Result  Past 4 Years Tournament Results      WIN%  \
# 0                             0.0                         1.250000  0.006629
# 1                            -1.0                        -1.000000 -0.093750
# 2                             0.0                        -0.750000  0.212702
# 3                             0.0                         0.000000  0.030303
# 4                            -7.0                        -3.250000  0.081439
# ...                           ...                              ...       ...
# 1379                         -2.0                        -0.333333 -0.016544
# 1380                          1.0                         1.000000 -0.176136
# 1381                          3.0                         0.666667  0.023674
# 1382                         -1.0                        -0.666667  0.093750
# 1383                          0.0                         0.000000  0.054924
#
#       ADJOE  ADJDE  ADJEM  BARTHAG  EFG%  EFGD%  TOR  TORD  ORB  FTR  FTRD  \
# 0       2.7   -7.1    9.8   0.1420  -1.2   -2.7  5.0   2.1  7.1 -3.4   2.2
# 1      -5.1    1.9   -7.0  -0.1138  -3.9    0.9 -0.3  -2.3 -3.3  7.2  -0.9
# 2      -0.3   -1.2    0.9   0.0132   4.7   -2.8  0.6  -0.7 -6.4  8.9  -4.7
# 3      13.0   -0.9   13.9   0.1917   4.0   -0.1 -1.6  -0.1 -5.2 -6.2   1.0
# 4       0.9    1.0   -0.1  -0.0023   2.7    3.9 -0.8   0.7 -4.6  4.3   0.8
# ...     ...    ...    ...      ...   ...    ...  ...   ...  ...  ...   ...
# 1379   -2.7   -9.8    7.1   0.0873  -2.3   -3.5  0.1   4.7 -3.7  1.5  10.4
# 1380    2.5    2.7   -0.2  -0.0056   4.2   -0.2 -1.0  -5.3 -6.2 -6.2  -9.6
# 1381   -1.6    8.9  -10.5  -0.1052   1.5    5.8 -2.5  -1.3 -7.2 -1.4 -14.6
# 1382    0.9    4.7   -3.8  -0.0447   4.9   -1.6 -0.9  -1.3 -1.3 -4.8  -2.7
# 1383   -7.6   -2.4   -5.2  -0.0289  -3.4    2.0 -1.3   0.2 -7.5  2.9  -9.3
#
#       ADJ T.  WAB  Past Year BARTHAG  Past 4 Years BARTHAG    Rating  \
# 0        0.4  7.4             0.0703              0.429650  1.160555
# 1       -4.0 -3.1            -0.0848             -0.167900 -1.103464
# 2        0.7  2.3            -0.0286             -0.026925  0.690981
# 3       -3.3  7.6             0.1886              0.008725  1.015935
# 4        3.0  1.4            -0.1929             -0.199375  0.131480
# ...      ...  ...                ...                   ...       ...
# 1379     0.0  3.8             0.0684              0.154450  0.292643
# 1380     1.8 -3.5            -0.0526              0.029250 -0.638693
# 1381     1.8 -1.3            -0.0240             -0.096625 -0.229468
# 1382     2.1 -1.0            -0.2767             -0.310225  0.192519
# 1383    -0.9  0.7            -0.0032              0.020900  0.009021
#
#       Efficiency Margin  Adjusted Offense  Adjusted Defense  Adjusted Tempo  \
# 0              0.067725          0.002941         -0.064784        0.583427
# 1             -0.086768         -0.061487          0.025281       -3.752108
# 2              0.029671          0.004867         -0.024804        0.670750
# 3              0.104575          0.097325         -0.007250       -3.019422
# 4              0.008000          0.021394          0.013394        2.322449
# ...                 ...               ...               ...             ...
# 1379           0.095063         -0.007959         -0.103022       -0.276751
# 1380           0.013201          0.032554          0.019353        1.681630
# 1381          -0.101200         -0.013950          0.087249        1.582331
# 1382           0.009792          0.030394          0.020602        2.299120
# 1383          -0.056638         -0.060985         -0.004348       -1.443680
#
#       Starters  Team A ADJOE Team B ADJDE  Team B ADJOE Team A ADJDE  \
# 0     0.111128                      215.1                      205.3
# 1    -0.219484                      196.5                      203.5
# 2     0.159773                      206.1                      205.2
# 3     0.108978                      216.5                      202.6
# 4    -0.032585                      205.5                      205.6
# ...        ...                        ...                        ...
# 1379  0.033572                      216.0                      208.9
# 1380 -0.100021                      203.9                      204.1
# 1381 -0.023358                      209.8                      220.3
# 1382  0.008468                      202.3                      206.1
# 1383  0.003144                      203.8                      209.0
#
#       Team A Offense Team B Defense  Team B Offense Team A Defense  \
# 0                          2.102834                       2.035109
# 1                          1.942389                       2.029157
# 2                          2.033802                       2.004131
# 3                          2.116883                       2.012308
# 4                          2.038228                       2.030228
# ...                             ...                            ...
# 1379                       2.143993                       2.048930
# 1380                       2.045875                       2.032673
# 1381                       2.064703                       2.165903
# 1382                       2.043715                       2.033922
# 1383                       2.017668                       2.074306
#
#       Team A BARTHAG  Team B BARTHAG
# 0             0.9090          0.7670
# 1             0.7615          0.8753
# 2             0.8612          0.8480
# 3             0.9184          0.7267
# 4             0.8553          0.8576
# ...              ...             ...
# 1379          0.9296          0.8423
# 1380          0.9130          0.9186
# 1381          0.8423          0.9475
# 1382          0.8739          0.9186
# 1383          0.9186          0.9475
#
# [1384 rows x 30 columns]

# %%
df_mod[df_features.columns] = df_features

df_mod
# Out:
#       Season  Round  Result  Team A ID        Team A  Team B ID  \
# 0       2012      1       1       1124        Baylor       1355
# 1       2012      1       1       1160      Colorado       1424
# 2       2012      1       1       1211       Gonzaga       1452
# 3       2012      1       1       1231       Indiana       1308
# 4       2012      1       1       1235       Iowa St       1163
# ...      ...    ...     ...        ...           ...        ...
# 1379    2023      4      -1       1400         Texas       1274
# 1380    2023      4      -1       1166     Creighton       1361
# 1381    2023      5      -1       1274      Miami FL       1163
# 1382    2023      5      -1       1194   FL Atlantic       1361
# 1383    2023      6      -1       1361  San Diego St       1163
#
#              Team B  Past Year Tournament Result  \
# 0       S Dakota St                          0.0
# 1              UNLV                         -1.0
# 2     West Virginia                          0.0
# 3     New Mexico St                          0.0
# 4       Connecticut                         -7.0
# ...             ...                          ...
# 1379       Miami FL                         -2.0
# 1380   San Diego St                          1.0
# 1381    Connecticut                          3.0
# 1382   San Diego St                         -1.0
# 1383    Connecticut                          0.0
#
#       Past 4 Years Tournament Results      WIN%  ADJOE  ADJDE  ADJEM  BARTHAG  \
# 0                            1.250000  0.006629    2.7   -7.1    9.8   0.1420
# 1                           -1.000000 -0.093750   -5.1    1.9   -7.0  -0.1138
# 2                           -0.750000  0.212702   -0.3   -1.2    0.9   0.0132
# 3                            0.000000  0.030303   13.0   -0.9   13.9   0.1917
# 4                           -3.250000  0.081439    0.9    1.0   -0.1  -0.0023
# ...                               ...       ...    ...    ...    ...      ...
# 1379                        -0.333333 -0.016544   -2.7   -9.8    7.1   0.0873
# 1380                         1.000000 -0.176136    2.5    2.7   -0.2  -0.0056
# 1381                         0.666667  0.023674   -1.6    8.9  -10.5  -0.1052
# 1382                        -0.666667  0.093750    0.9    4.7   -3.8  -0.0447
# 1383                         0.000000  0.054924   -7.6   -2.4   -5.2  -0.0289
#
#       EFG%  EFGD%  TOR  TORD  ORB  FTR  FTRD  ADJ T.  WAB  Past Year BARTHAG  \
# 0     -1.2   -2.7  5.0   2.1  7.1 -3.4   2.2     0.4  7.4             0.0703
# 1     -3.9    0.9 -0.3  -2.3 -3.3  7.2  -0.9    -4.0 -3.1            -0.0848
# 2      4.7   -2.8  0.6  -0.7 -6.4  8.9  -4.7     0.7  2.3            -0.0286
# 3      4.0   -0.1 -1.6  -0.1 -5.2 -6.2   1.0    -3.3  7.6             0.1886
# 4      2.7    3.9 -0.8   0.7 -4.6  4.3   0.8     3.0  1.4            -0.1929
# ...    ...    ...  ...   ...  ...  ...   ...     ...  ...                ...
# 1379  -2.3   -3.5  0.1   4.7 -3.7  1.5  10.4     0.0  3.8             0.0684
# 1380   4.2   -0.2 -1.0  -5.3 -6.2 -6.2  -9.6     1.8 -3.5            -0.0526
# 1381   1.5    5.8 -2.5  -1.3 -7.2 -1.4 -14.6     1.8 -1.3            -0.0240
# 1382   4.9   -1.6 -0.9  -1.3 -1.3 -4.8  -2.7     2.1 -1.0            -0.2767
# 1383  -3.4    2.0 -1.3   0.2 -7.5  2.9  -9.3    -0.9  0.7            -0.0032
#
#       Past 4 Years BARTHAG    Rating  Efficiency Margin  Adjusted Offense  \
# 0                 0.429650  1.160555           0.067725          0.002941
# 1                -0.167900 -1.103464          -0.086768         -0.061487
# 2                -0.026925  0.690981           0.029671          0.004867
# 3                 0.008725  1.015935           0.104575          0.097325
# 4                -0.199375  0.131480           0.008000          0.021394
# ...                    ...       ...                ...               ...
# 1379              0.154450  0.292643           0.095063         -0.007959
# 1380              0.029250 -0.638693           0.013201          0.032554
# 1381             -0.096625 -0.229468          -0.101200         -0.013950
# 1382             -0.310225  0.192519           0.009792          0.030394
# 1383              0.020900  0.009021          -0.056638         -0.060985
#
#       Adjusted Defense  Adjusted Tempo  Starters  Team A ADJOE Team B ADJDE  \
# 0            -0.064784        0.583427  0.111128                      215.1
# 1             0.025281       -3.752108 -0.219484                      196.5
# 2            -0.024804        0.670750  0.159773                      206.1
# 3            -0.007250       -3.019422  0.108978                      216.5
# 4             0.013394        2.322449 -0.032585                      205.5
# ...                ...             ...       ...                        ...
# 1379         -0.103022       -0.276751  0.033572                      216.0
# 1380          0.019353        1.681630 -0.100021                      203.9
# 1381          0.087249        1.582331 -0.023358                      209.8
# 1382          0.020602        2.299120  0.008468                      202.3
# 1383         -0.004348       -1.443680  0.003144                      203.8
#
#       Team B ADJOE Team A ADJDE  Team A Offense Team B Defense  \
# 0                         205.3                       2.102834
# 1                         203.5                       1.942389
# 2                         205.2                       2.033802
# 3                         202.6                       2.116883
# 4                         205.6                       2.038228
# ...                         ...                            ...
# 1379                      208.9                       2.143993
# 1380                      204.1                       2.045875
# 1381                      220.3                       2.064703
# 1382                      206.1                       2.043715
# 1383                      209.0                       2.017668
#
#       Team B Offense Team A Defense  Team A BARTHAG  Team B BARTHAG
# 0                          2.035109          0.9090          0.7670
# 1                          2.029157          0.7615          0.8753
# 2                          2.004131          0.8612          0.8480
# 3                          2.012308          0.9184          0.7267
# 4                          2.030228          0.8553          0.8576
# ...                             ...             ...             ...
# 1379                       2.048930          0.9296          0.8423
# 1380                       2.032673          0.9130          0.9186
# 1381                       2.165903          0.8423          0.9475
# 1382                       2.033922          0.8739          0.9186
# 1383                       2.074306          0.9186          0.9475
#
# [1384 rows x 37 columns]

# %%
df_mod.to_csv('../data/preprocessed/model_data/model_data.csv', index=False)

'Done'
# Out:
# 'Done'
